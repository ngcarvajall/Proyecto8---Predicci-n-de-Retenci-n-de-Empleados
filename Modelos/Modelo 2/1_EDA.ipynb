# %%
# %load_ext autoreload
# %autoreload 2

# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd
from itertools import product
from itertools import combinations
from scipy.stats import chi2_contingency
# Otros objetivos
# -----------------------------------------------------------------------
import math
# Funciones
import sys
sys.path.append('../../') #pongo los 2 puntos para que salga de la carpeta
import src.funciones as f
import src.soporte_prep as spp

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# Nulos 
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
from sklearn.linear_model import BayesianRidge
from sklearn.impute import IterativeImputer
from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_general = pd.read_csv('../../Datos/general_data.csv')
df_employee_survey = pd.read_csv('../../Datos/employee_survey_data.csv')
df_manager_survey = pd.read_csv('../../Datos/manager_survey_data.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data frame general

# %%
df_general.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# 1         Research Scientist        Single          41890                 0.0
# 2            Sales Executive       Married         193280                 1.0
# 3            Human Resources       Married          83210                 3.0
# 4            Sales Executive        Single          23420                 4.0
#
#   Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 0      Y                 11              8                 0
# 1      Y                 23              8                 1
# 2      Y                 15              8                 3
# 3      Y                 11              8                 3
# 4      Y                 12              8                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0                      6               1
# 1                6.0                      3               5
# 2                5.0                      2               5
# 3               13.0                      5               8
# 4                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4

# %%
df_general.shape
# Out:
# (4410, 24)

# %%
df_general.nunique()
# Out:
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# EmployeeID                 4410
# Gender                        2
# JobLevel                      5
# JobRole                       9
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# Over18                        1
# PercentSalaryHike            15
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# dtype: int64

# %% [markdown]
# De esta forma, puedo comprobar las categorías en las variables del mismo tipo.

# %%
df_general.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# Aquí voy observando los nulos que tengo en mis datos, señalando que solo tengo nulos en una columna: NumCompaniesWorked (19 nulos).

# %% [markdown]
# ## Datos de la encuesta a empleados

# %%
df_employee_survey.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
df_employee_survey.nunique()
# Out:
# EmployeeID                 4410
# EnvironmentSatisfaction       4
# JobSatisfaction               4
# WorkLifeBalance               4
# dtype: int64

# %%
df_employee_survey.isna().sum()
# Out:
# EmployeeID                  0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %% [markdown]
# En la encuesta realizada a los empleados, puedo observar que tengo nulos en todas las variables que hacen referencia a las preguntas de la encuesta. Sin embargo, no tengo nulos en el EmployeeID lo que me indica buena señal.

# %% [markdown]
# ## Datos de la encuesta realizada a los managers

# %%
df_manager_survey.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
df_manager_survey.nunique()
# Out:
# EmployeeID           4410
# JobInvolvement          4
# PerformanceRating       2
# dtype: int64

# %%
df_manager_survey.isna().sum()
# Out:
# EmployeeID           0
# JobInvolvement       0
# PerformanceRating    0
# dtype: int64

# %% [markdown]
# En la encuesta realizada a los managers, no tengo nulos en ningún lugar.

# %% [markdown]
# ## Mergeo

# %%
df_mergeo = df_general.merge(df_employee_survey, on='EmployeeID', how='inner') \
               .merge(df_manager_survey, on='EmployeeID', how='inner')

# %%
df_mergeo.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# 1         Research Scientist        Single          41890                 0.0
# 2            Sales Executive       Married         193280                 1.0
# 3            Human Resources       Married          83210                 3.0
# 4            Sales Executive        Single          23420                 4.0
#
#   Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 0      Y                 11              8                 0
# 1      Y                 23              8                 1
# 2      Y                 15              8                 3
# 3      Y                 11              8                 3
# 4      Y                 12              8                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0                      6               1
# 1                6.0                      3               5
# 2                5.0                      2               5
# 3               13.0                      5               8
# 4                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# 0                        0                     0                      3.0
# 1                        1                     4                      3.0
# 2                        0                     3                      2.0
# 3                        7                     5                      4.0
# 4                        0                     4                      4.0
#
#    JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0              4.0              2.0               3                  3
# 1              2.0              4.0               2                  4
# 2              2.0              1.0               3                  3
# 3              4.0              3.0               2                  3
# 4              1.0              3.0               3                  3

# %%
df_mergeo.shape
# Out:
# (4410, 29)

# %%
df_mergeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
#  14  NumCompaniesWorked       4391 non-null   float64
#  15  Over18                   4410 non-null   object
#  16  PercentSalaryHike        4410 non-null   int64
#  17  StandardHours            4410 non-null   int64
#  18  StockOptionLevel         4410 non-null   int64
#  19  TotalWorkingYears        4401 non-null   float64
#  20  TrainingTimesLastYear    4410 non-null   int64
#  21  YearsAtCompany           4410 non-null   int64
#  22  YearsSinceLastPromotion  4410 non-null   int64
#  23  YearsWithCurrManager     4410 non-null   int64
#  24  EnvironmentSatisfaction  4385 non-null   float64
#  25  JobSatisfaction          4390 non-null   float64
#  26  WorkLifeBalance          4372 non-null   float64
#  27  JobInvolvement           4410 non-null   int64
#  28  PerformanceRating        4410 non-null   int64
# dtypes: float64(5), int64(16), object(8)
# memory usage: 999.3+ KB

# %%
df_mergeo.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %% [markdown]
# He identificado que tengo 4 columnas con nulo, más adelante veo qué puedo hacer.

# %%
df_mergeo[pd.isnull(df_mergeo['NumCompaniesWorked'])]
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 115    27        No      Travel_Rarely                   Sales
# 210    52        No      Travel_Rarely                   Sales
# 343    40        No  Travel_Frequently                   Sales
# 476    22        No      Travel_Rarely  Research & Development
# 647    29        No      Travel_Rarely  Research & Development
# 799    29       Yes  Travel_Frequently  Research & Development
# 932    32        No      Travel_Rarely  Research & Development
# 1103   26        No  Travel_Frequently                   Sales
# 1312   37       Yes      Travel_Rarely         Human Resources
# 1521   31        No      Travel_Rarely  Research & Development
# 1711   33        No      Travel_Rarely                   Sales
# 1996   38        No      Travel_Rarely  Research & Development
# 2365   18       Yes  Travel_Frequently  Research & Development
# 2696   28       Yes      Travel_Rarely  Research & Development
# 3063   30        No      Travel_Rarely  Research & Development
# 3533   56        No      Travel_Rarely  Research & Development
# 3910   41        No         Non-Travel                   Sales
# 4226   36        No      Travel_Rarely  Research & Development
# 4395   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 115                  2          3     Life Sciences              1
# 210                  2          1           Medical              1
# 343                  9          3         Marketing              1
# 476                  8          3             Other              1
# 647                  3          3  Technical Degree              1
# 799                 28          3           Medical              1
# 932                  5          4  Technical Degree              1
# 1103                16          2     Life Sciences              1
# 1312                 9          3   Human Resources              1
# 1521                20          1  Technical Degree              1
# 1711                13          4         Marketing              1
# 1996                 5          3  Technical Degree              1
# 2365                 3          5           Medical              1
# 2696                 1          4     Life Sciences              1
# 3063                 3          3     Life Sciences              1
# 3533                 3          2             Other              1
# 3910                 2          2           Medical              1
# 4226                 2          3     Life Sciences              1
# 4395                 2          3     Life Sciences              1
#
#       EmployeeID  Gender  JobLevel                    JobRole MaritalStatus  \
# 115          116    Male         1            Sales Executive      Divorced
# 210          211    Male         1      Laboratory Technician      Divorced
# 343          344    Male         3     Manufacturing Director        Single
# 476          477    Male         2       Sales Representative       Married
# 647          648  Female         2  Healthcare Representative      Divorced
# 799          800  Female         5         Research Scientist        Single
# 932          933    Male         5         Research Scientist      Divorced
# 1103        1104    Male         2  Healthcare Representative       Married
# 1312        1313    Male         2  Healthcare Representative      Divorced
# 1521        1522  Female         3         Research Scientist       Married
# 1711        1712  Female         2     Manufacturing Director      Divorced
# 1996        1997    Male         1            Sales Executive       Married
# 2365        2366    Male         1          Research Director        Single
# 2696        2697    Male         5          Research Director        Single
# 3063        3064  Female         2                    Manager       Married
# 3533        3534    Male         2  Healthcare Representative      Divorced
# 3910        3911    Male         2         Research Scientist       Married
# 4226        4227    Male         2       Sales Representative       Married
# 4395        4396    Male         1     Manufacturing Director      Divorced
#
#       MonthlyIncome  NumCompaniesWorked Over18  PercentSalaryHike  \
# 115           23670                 NaN      Y                 12
# 210           99800                 NaN      Y                 11
# 343           22380                 NaN      Y                 14
# 476           49070                 NaN      Y                 21
# 647           48050                 NaN      Y                 16
# 799           44340                 NaN      Y                 17
# 932           50030                 NaN      Y                 13
# 1103          83800                 NaN      Y                 14
# 1312          54840                 NaN      Y                 17
# 1521          99070                 NaN      Y                 13
# 1711          45680                 NaN      Y                 18
# 1996          63490                 NaN      Y                 11
# 2365          24790                 NaN      Y                 12
# 2696         100960                 NaN      Y                 13
# 3063          59680                 NaN      Y                 13
# 3533          44490                 NaN      Y                 15
# 3910         107980                 NaN      Y                 14
# 4226          43200                 NaN      Y                 17
# 4395          27180                 NaN      Y                 14
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 115               8                 1                5.0
# 210               8                 1               18.0
# 343               8                 0               10.0
# 476               8                 1                4.0
# 647               8                 1                9.0
# 799               8                 3                7.0
# 932               8                 0               10.0
# 1103              8                 0                8.0
# 1312              8                 0                7.0
# 1521              8                 1                6.0
# 1711              8                 1                6.0
# 1996              8                 0               20.0
# 2365              8                 1                0.0
# 2696              8                 0                6.0
# 3063              8                 0                1.0
# 3533              8                 0               28.0
# 3910              8                 2               10.0
# 4226              8                 0                5.0
# 4395              8                 1                9.0
#
#       TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 115                       2               5                        0
# 210                       2              10                        6
# 343                       3               1                        0
# 476                       2               4                        1
# 647                       2               7                        1
# 799                       1               5                        0
# 932                       5               9                        1
# 1103                      3               7                        7
# 1312                      4               3                        0
# 1521                      3               5                        0
# 1711                      2               5                        1
# 1996                      3              19                        1
# 2365                      2               0                        0
# 2696                      2               4                        0
# 3063                      3               1                        0
# 3533                      3               5                        4
# 3910                      5               3                        1
# 4226                      2               1                        0
# 4395                      4               9                        4
#
#       YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  \
# 115                      4                      4.0              2.0
# 210                      9                      4.0              1.0
# 343                      0                      1.0              3.0
# 476                      1                      2.0              1.0
# 647                      7                      4.0              4.0
# 799                      0                      1.0              2.0
# 932                      6                      4.0              2.0
# 1103                     7                      3.0              4.0
# 1312                     2                      3.0              1.0
# 1521                     3                      3.0              4.0
# 1711                     2                      3.0              3.0
# 1996                     9                      3.0              3.0
# 2365                     0                      2.0              4.0
# 2696                     3                      3.0              3.0
# 3063                     0                      3.0              2.0
# 3533                     2                      4.0              1.0
# 3910                     2                      3.0              2.0
# 4226                     0                      2.0              4.0
# 4395                     7                      1.0              4.0
#
#       WorkLifeBalance  JobInvolvement  PerformanceRating
# 115               3.0               3                  3
# 210               3.0               3                  3
# 343               3.0               3                  3
# 476               2.0               3                  4
# 647               2.0               3                  3
# 799               1.0               3                  3
# 932               2.0               3                  3
# 1103              3.0               4                  3
# 1312              3.0               3                  3
# 1521              3.0               2                  3
# 1711              3.0               3                  3
# 1996              2.0               3                  3
# 2365              4.0               2                  3
# 2696              3.0               3                  3
# 3063              3.0               3                  3
# 3533              3.0               1                  3
# 3910              3.0               1                  3
# 4226              3.0               3                  3
# 4395              3.0               2                  3

# %%
df_mergeo.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# std       1.106689   47068.888559            2.498887           3.659108
# min       1.000000   10090.000000            0.000000          11.000000
# 25%       1.000000   29110.000000            1.000000          12.000000
# 50%       2.000000   49190.000000            2.000000          14.000000
# 75%       3.000000   83800.000000            4.000000          18.000000
# max       5.000000  199990.000000            9.000000          25.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         4410.0       4410.000000        4401.000000
# mean             8.0          0.793878          11.279936
# std              0.0          0.851883           7.782222
# min              8.0          0.000000           0.000000
# 25%              8.0          0.000000           6.000000
# 50%              8.0          1.000000          10.000000
# 75%              8.0          1.000000          15.000000
# max              8.0          3.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# count            4410.000000     4410.000000              4410.000000
# mean                2.799320        7.008163                 2.187755
# std                 1.288978        6.125135                 3.221699
# min                 0.000000        0.000000                 0.000000
# 25%                 2.000000        3.000000                 0.000000
# 50%                 3.000000        5.000000                 1.000000
# 75%                 3.000000        9.000000                 3.000000
# max                 6.000000       40.000000                15.000000
#
#        YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  \
# count           4410.000000              4385.000000      4390.000000
# mean               4.123129                 2.723603         2.728246
# std                3.567327                 1.092756         1.101253
# min                0.000000                 1.000000         1.000000
# 25%                2.000000                 2.000000         2.000000
# 50%                3.000000                 3.000000         3.000000
# 75%                7.000000                 4.000000         4.000000
# max               17.000000                 4.000000         4.000000
#
#        WorkLifeBalance  JobInvolvement  PerformanceRating
# count      4372.000000     4410.000000        4410.000000
# mean          2.761436        2.729932           3.153741
# std           0.706245        0.711400           0.360742
# min           1.000000        1.000000           3.000000
# 25%           2.000000        2.000000           3.000000
# 50%           3.000000        3.000000           3.000000
# 75%           3.000000        3.000000           3.000000
# max           4.000000        4.000000           4.000000

# %%
df_mergeo.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %% [markdown]
# ## Exploración

# %%
f.exploracion_dataframe(df_mergeo, 'Attrition')
# Out:
# El número de datos es 4410 y el de columnas es 29
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                           %_nulos
# NumCompaniesWorked       0.430839
# TotalWorkingYears        0.204082
# EnvironmentSatisfaction  0.566893
# JobSatisfaction          0.453515
# WorkLifeBalance          0.861678
#  .....................
#
# Los tipos de las columnas son:
#                         tipo_dato
# Age                         int64
# Attrition                  object
# BusinessTravel             object
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EmployeeCount               int64
# EmployeeID                  int64
# Gender                     object
# JobLevel                    int64
# JobRole                    object
# MaritalStatus              object
# MonthlyIncome               int64
# NumCompaniesWorked        float64
# Over18                     object
# PercentSalaryHike           int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears         float64
# TrainingTimesLastYear       int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# EnvironmentSatisfaction   float64
# JobSatisfaction           float64
# WorkLifeBalance           float64
# JobInvolvement              int64
# PerformanceRating           int64
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna Attrition tiene los siguientes valores únicos:
#            count
# Attrition
# No          3699
# Yes          711
# La columna BusinessTravel tiene los siguientes valores únicos:
#                    count
# BusinessTravel
# Travel_Rarely       3129
# Travel_Frequently    831
# Non-Travel           450
# La columna Department tiene los siguientes valores únicos:
#                         count
# Department
# Research & Development   2883
# Sales                    1338
# Human Resources           189
# La columna EducationField tiene los siguientes valores únicos:
#                   count
# EducationField
# Life Sciences      1818
# Medical            1392
# Marketing           477
# Technical Degree    396
# Other               246
# Human Resources      81
# La columna Gender tiene los siguientes valores únicos:
#         count
# Gender
# Male     2646
# Female   1764
# La columna JobRole tiene los siguientes valores únicos:
#                            count
# JobRole
# Sales Executive              978
# Research Scientist           876
# Laboratory Technician        777
# Manufacturing Director       435
# Healthcare Representative    393
# Manager                      306
# Sales Representative         249
# Research Director            240
# Human Resources              156
# La columna MaritalStatus tiene los siguientes valores únicos:
#                count
# MaritalStatus
# Married         2019
# Single          1410
# Divorced         981
# La columna Over18 tiene los siguientes valores únicos:
#         count
# Over18
# Y        4410

# %% [markdown]
# ### Observaciones:
# - No tenemos duplicados, tenemos un conjunto de datos de 4,410 empleados con unas 29 columnas (luego de haber unido mis 3 conjuntos de datos).
# - Hay nulos en 5 columnas.
# - Existe desbalanceo en mi variable respuesta 'Attrition.
# - Existen columnas numéricas que en realidad son categóricas, i.e. Education.
# - Existen 2 columnas que no aportan datos: EmployeeCount (hace un conteo a uno de cada empleado) y over18(que confirma si el empleado tiene más de 18 años, cosa que queda reafirmada ya en una columna de Edad)
#
# - En el último año se han ido de la empresa 711 personas (16%).
# - Tengo una población mayormente masculina (60%)
# - En su mayoría son personas casadas, por encima de los solteros y divorciados (45%)
# - Tengo una media de edad de 36 años, con una desviación estándar de 9 años.

# %%
df_mergeo.drop(columns=['Over18', 'EmployeeCount', 'StandardHours', 'EmployeeID'], inplace=True)

# %% [markdown]
# Estas columnas en sí no aportan nada, me las llevo.

# %%
df_mergeo.shape
# Out:
# (4410, 25)

# %% [markdown]
# Vamos a mappear mi columna Attrition, para ya dejar claro si se ha ido o no en el último año de manera numérica.

# %% [markdown]
# - Anteriormente teníamos una columna (EmployeeID) que nos identificaba de manera individual a cada persona. Ya que la hemos eliminado, veamos si encontramos duplicados.

# %%
df_mergeo[df_mergeo.duplicated()]
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1471   31       Yes  Travel_Frequently  Research & Development
# 1472   32        No  Travel_Frequently  Research & Development
# 1473   38        No         Non-Travel  Research & Development
# 1474   32        No      Travel_Rarely  Research & Development
# 1475   46        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 1471                10          1  Life Sciences  Female         1
# 1472                17          4          Other    Male         4
# 1473                 2          5  Life Sciences    Male         3
# 1474                10          1        Medical    Male         1
# 1475                 8          3  Life Sciences  Female         4
# ...                ...        ...            ...     ...       ...
# 4404                 4          3          Other  Female         2
# 4405                 5          4        Medical  Female         1
# 4406                 2          4        Medical    Male         1
# 4407                25          2  Life Sciences    Male         2
# 4408                18          2        Medical    Male         1
#
#                     JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 1471     Research Scientist        Single          41890                 0.0
# 1472        Sales Executive       Married         193280                 1.0
# 1473        Human Resources       Married          83210                 3.0
# 1474        Sales Executive        Single          23420                 4.0
# 1475      Research Director       Married          40710                 3.0
# ...                     ...           ...            ...                 ...
# 4404        Human Resources        Single          35390                 1.0
# 4405     Research Scientist        Single          60290                 3.0
# 4406  Laboratory Technician      Divorced          26790                 2.0
# 4407        Sales Executive       Married          37020                 0.0
# 4408  Laboratory Technician      Divorced          23980                 0.0
#
#       PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 1471                 23                 1                6.0
# 1472                 15                 3                5.0
# 1473                 11                 3               13.0
# 1474                 12                 2                9.0
# 1475                 13                 0               28.0
# ...                 ...               ...                ...
# 4404                 18                 0                6.0
# 4405                 17                 1               10.0
# 4406                 15                 0               10.0
# 4407                 20                 0                5.0
# 4408                 14                 1               10.0
#
#       TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 1471                      3               5                        1
# 1472                      2               5                        0
# 1473                      5               8                        7
# 1474                      2               6                        0
# 1475                      5               7                        7
# ...                     ...             ...                      ...
# 4404                      2               6                        1
# 4405                      5               3                        0
# 4406                      2               3                        0
# 4407                      4               4                        1
# 4408                      2               9                        7
#
#       YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  \
# 1471                     4                      3.0              2.0
# 1472                     3                      2.0              2.0
# 1473                     5                      4.0              4.0
# 1474                     4                      4.0              1.0
# 1475                     7                      3.0              2.0
# ...                    ...                      ...              ...
# 4404                     5                      3.0              4.0
# 4405                     2                      4.0              1.0
# 4406                     2                      4.0              4.0
# 4407                     2                      1.0              3.0
# 4408                     8                      4.0              1.0
#
#       WorkLifeBalance  JobInvolvement  PerformanceRating
# 1471              4.0               2                  4
# 1472              1.0               3                  3
# 1473              3.0               2                  3
# 1474              3.0               3                  3
# 1475              2.0               3                  3
# ...               ...             ...                ...
# 4404              3.0               2                  3
# 4405              3.0               3                  3
# 4406              3.0               2                  3
# 4407              3.0               3                  4
# 4408              3.0               2                  3
#
# [2837 rows x 25 columns]

# %% [markdown]
# - Al volver a verificar nuestros datos, nos hemos encontrado que existe una alta cantidad de duplicados. Esto puede ser producto de una recolección de datos que no haya sido clara y/o efectiva. Al identificar estos usuarios con un único ID podíamos pasar por alto esto, pero una vez eliminada dicha columna nos encontramos con el detalle de que más de 2000 empleados poseen las mismas características, idénticas. Esto no tienen mucho sentido al considerar que tenemos en cuenta más de 20 variables distintas. Por esta razón, vamos a eliminar los duplicados.

# %%
duplicados = df_mergeo.duplicated().sum()
porcentaje_duplicados = (duplicados / len(df_mergeo)) * 100

# %%
print(f"Cantidad de duplicados: {duplicados}")
print(f"Porcentaje de duplicados: {porcentaje_duplicados:.2f}%")
# Out:
# Cantidad de duplicados: 2837
# Porcentaje de duplicados: 64.33%

# %% [markdown]
# - Como muestro, la cantidad de duplicados está por encima del 50% de mis datos originales, lo que nos hace ver que la recolección original de estos datos tuvo ciertos inconvenientes.

# %%
df_mergeo.drop_duplicates(inplace=True)

# %%
df_mergeo.shape
# Out:
# (1573, 25)

# %% [markdown]
# Al eliminar una gran cantidad de duplicados, nos quedamos con un conjunto de datos que no tendrá duplicados para sobre-entrenarse por lo que las métricas esperadas deberían no ser tan buenas.

# %%
df_num, df_cat = f.separar_dataframes(df_mergeo)

# %%
df_mergeo.describe()
# Out:
#                Age  DistanceFromHome    Education     JobLevel  MonthlyIncome  \
# count  1573.000000       1573.000000  1573.000000  1573.000000    1573.000000
# mean     36.904005          9.158296     2.911634     2.056580   64979.459631
# std       9.105911          8.124414     1.022867     1.108022   47121.739301
# min      18.000000          1.000000     1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000     1.000000   28990.000000
# 50%      36.000000          7.000000     3.000000     2.000000   49000.000000
# 75%      43.000000         14.000000     4.000000     3.000000   83800.000000
# max      60.000000         29.000000     5.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count         1554.000000        1573.000000       1573.000000
# mean             2.703990          15.202161          0.790210
# std              2.508432           3.646403          0.848876
# min              0.000000          11.000000          0.000000
# 25%              1.000000          12.000000          0.000000
# 50%              2.000000          14.000000          1.000000
# 75%              4.000000          18.000000          1.000000
# max              9.000000          25.000000          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# count        1564.000000            1573.000000     1573.000000
# mean           11.245524               2.807374        6.970757
# std             7.748763               1.287203        6.068348
# min             0.000000               0.000000        0.000000
# 25%             6.000000               2.000000        3.000000
# 50%            10.000000               3.000000        5.000000
# 75%            15.000000               3.000000        9.000000
# max            40.000000               6.000000       40.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# count              1573.000000           1573.000000              1550.000000
# mean                  2.184361              4.102988                 2.718065
# std                   3.203105              3.572701                 1.090423
# min                   0.000000              0.000000                 1.000000
# 25%                   0.000000              2.000000                 2.000000
# 50%                   1.000000              3.000000                 3.000000
# 75%                   3.000000              7.000000                 4.000000
# max                  15.000000             17.000000                 4.000000
#
#        JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# count      1555.000000      1538.000000     1573.000000        1573.000000
# mean          2.737621         2.761378        2.732994           3.152575
# std           1.100763         0.701994        0.712421           0.359691
# min           1.000000         1.000000        1.000000           3.000000
# 25%           2.000000         2.000000        2.000000           3.000000
# 50%           3.000000         3.000000        3.000000           3.000000
# 75%           4.000000         3.000000        3.000000           3.000000
# max           4.000000         4.000000        4.000000           4.000000

# %%
df_mergeo.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1573           1573                    1573           1573   1573
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1321           1117                    1030            655    953
#
#                 JobRole MaritalStatus
# count              1573          1573
# unique                9             3
# top     Sales Executive       Married
# freq                348           720

# %%
f.exploracion_dataframe(df_mergeo, 'Attrition')
# Out:
# El número de datos es 1573 y el de columnas es 25
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                           %_nulos
# NumCompaniesWorked       1.207883
# TotalWorkingYears        0.572155
# EnvironmentSatisfaction  1.462174
# JobSatisfaction          1.144310
# WorkLifeBalance          2.225048
#  .....................
#
# Los tipos de las columnas son:
#                         tipo_dato
# Age                         int64
# Attrition                  object
# BusinessTravel             object
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# Gender                     object
# JobLevel                    int64
# JobRole                    object
# MaritalStatus              object
# MonthlyIncome               int64
# NumCompaniesWorked        float64
# PercentSalaryHike           int64
# StockOptionLevel            int64
# TotalWorkingYears         float64
# TrainingTimesLastYear       int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# EnvironmentSatisfaction   float64
# JobSatisfaction           float64
# WorkLifeBalance           float64
# JobInvolvement              int64
# PerformanceRating           int64
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna Attrition tiene los siguientes valores únicos:
#            count
# Attrition
# No          1321
# Yes          252
# La columna BusinessTravel tiene los siguientes valores únicos:
#                    count
# BusinessTravel
# Travel_Rarely       1117
# Travel_Frequently    297
# Non-Travel           159
# La columna Department tiene los siguientes valores únicos:
#                         count
# Department
# Research & Development   1030
# Sales                     477
# Human Resources            66
# La columna EducationField tiene los siguientes valores únicos:
#                   count
# EducationField
# Life Sciences       655
# Medical             489
# Marketing           167
# Technical Degree    144
# Other                90
# Human Resources      28
# La columna Gender tiene los siguientes valores únicos:
#         count
# Gender
# Male      953
# Female    620
# La columna JobRole tiene los siguientes valores únicos:
#                            count
# JobRole
# Sales Executive              348
# Research Scientist           308
# Laboratory Technician        278
# Manufacturing Director       157
# Healthcare Representative    145
# Manager                      107
# Sales Representative          91
# Research Director             85
# Human Resources               54
# La columna MaritalStatus tiene los siguientes valores únicos:
#                count
# MaritalStatus
# Married          720
# Single           496
# Divorced         357

# %% [markdown]
# Luego de explorar los datos, ya sin duplicados, me doy cuenta de que en las variables categóricas se mantiene el orden de categorías. Se diminuye en cantidad pero las que eran representativas para el conjunto completo, siguen estando en el top de cada una.

# %%
df_mergeo['Attrition'] = df_mergeo['Attrition'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# ## Visualizaciones

# %%
f.plot_numericas(df_num, figsize=(15,10))

# %% [markdown]
# Con esta visualización puedo comprobar la distribución de mis variables. De igual forma, veo cuáles corresponden mejor a variables categóricas que a numéricas.

# %%
df_mergeo['Education'] = df_mergeo['Education'].astype('category')
df_mergeo['JobLevel'] = df_mergeo['JobLevel'].astype('category')
df_mergeo['StockOptionLevel'] = df_mergeo['StockOptionLevel'].astype('category')
df_mergeo['EnvironmentSatisfaction'] = df_mergeo['EnvironmentSatisfaction'].astype('O')
df_mergeo['JobSatisfaction'] = df_mergeo['JobSatisfaction'].astype('O')
df_mergeo['WorkLifeBalance'] = df_mergeo['WorkLifeBalance'].astype('O')
df_mergeo['JobInvolvement'] = df_mergeo['JobInvolvement'].astype('category')
df_mergeo['PerformanceRating'] = df_mergeo['PerformanceRating'].astype('category')
df_mergeo['TrainingTimesLastYear'] = df_mergeo['TrainingTimesLastYear'].astype('category')
df_mergeo['NumCompaniesWorked'] = df_mergeo['NumCompaniesWorked'].astype('category')

# %%
f.plot_categoricas(df_cat)

# %% [markdown]
# Con relación a mis variables categóricas, aquí puedo ver el conteo de sus categorías desde la que más presencia tiene hasta la de menor presencia.

# %%
f.matriz_correlacion(df_mergeo, figsize=(10,8))

# %% [markdown]
# ## Observaciones respecto a las correlaciones:
# - Se observa una correlación positiva entre los años de trabajo y la edad (0.68). Tiene sentido que se relacionen ya que estas pueden tener mucha congruencia.
# - Los años en la compañía y el tiempo de trabajo también presentan una correlación positiva (0.62). Representa una relación lógica en el ámbito laboral.
# - El tiempo en la compañía y los años bajo el mismo manager también presentan una alta correlación (0.77). Esta, por igual, tiene mucho sentido a la hora de una buena relación laboral. Si esto es positivo normalmente arroja un buen trabajo de los gerentes o supervisores.

# %% [markdown]
# ### Llamada a la clase del src

# %%
visuales = spp.Visualizador(df_mergeo)

# %%
visuales.plot_relacion('Attrition')
# Out:
# BusinessTravel
# Department
# Education
# EducationField
# Gender
# JobLevel
# JobRole
# MaritalStatus
# StockOptionLevel
# TrainingTimesLastYear
# EnvironmentSatisfaction
# JobSatisfaction
# WorkLifeBalance
# JobInvolvement
# PerformanceRating

# %% [markdown]
# ## Relaciones VR con variables numéricas

# %%
f.graficar_relaciones_numericas(df_mergeo, 'Attrition')

# %% [markdown]
# ## Observaciones:
# - Podemos mencionar que:
#     - Antes de llegar a los 30 años, es que se presenta el punto más alto entre los empleados que se fueron en el año anterior. A partir de este punto, los valores empiezan a disminuir.
#     - Aquellos que se encuentran a menor distancia son los que, en su mayoría, se fueron.
#     - En cuanto a salario, aquellos que se mantienen por debajo de la media son los que mayormente se fueron. Tomo la media como referencia porque esta es más alta, la mediana que es inferior se encuentra dentro de este grupos de salidas.
#     - En relación al PErcentSalaryHike, no se ven patrones muy relevantes a señalar pero sí se puede comentar que aquellos con menor pocentaje de aumento son los que se presentan más en los casos de salidas.
#     - En los años trabajados en total, el primer año es el que tiene más presencia de salida. Esto quiere decir que existe algo que sucede aquí porque también hay mucha salida en el primer año en la compañía para muchas personas. Esto se ve reflejado en el primer año dentro de todas las posibles circunstancias porque se refleja en el primer año bajo un mismo manager y en el primer año desde el cual se ha recibido un ascenso.

# %%
f.graficar_relaciones_categoricas(df_mergeo,'Attrition')

# %% [markdown]
# ## Observaciones:
# - Aquellos que viajan con poco frecuencia son los más propensos a salir.
# - Dentro del departamento de investigación y desarrollo se encuentra la mayor fuga de empleados.
# - En Education, se ve un aumento en la salida hasta llegar

# %%
visuales.deteccion_outliers()

# %% [markdown]
# ## Outliers univariados:
# - Por encima de los 160,000 se observan una serie de univariados que destancan como outliers.
# - En los años totales de trabajo, por encima de los 30 años se presentan los outliers.
# - Casi al llegar los 20 años en la compañia, esos datos se presentan como outliers.
# - Poco después de los 5 años sin recibir una promoción, estas personas que se encuentran en este segmento mayor parecen ser outliers.
# - Después de 15 años bajo el mismo gerente, parecen ser outliers también.

# %% [markdown]
# ## Cambio de moneda para entender mejor el contexto

# %%
tasa_de_cambio = 0.0113

df_mergeo['MonthlyIncome'] = df_mergeo['MonthlyIncome'].apply(lambda x: x * tasa_de_cambio)

# %% [markdown]
# ## Imputar nulos

# %% [markdown]
# Mis nulos están en las siguientes columnas: NumCompaniesWorked, EnvironmentSatisfaction, JobSatisfaction, WorkLifeBalance. Sin embargo, solo una de ellas es numérica (NumCompaniesWorked).

# %%
df_mergeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   int64
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   category
#  6   EducationField           4410 non-null   object
#  7   Gender                   4410 non-null   object
#  8   JobLevel                 4410 non-null   category
#  9   JobRole                  4410 non-null   object
#  10  MaritalStatus            4410 non-null   object
#  11  MonthlyIncome            4410 non-null   float64
#  12  NumCompaniesWorked       4391 non-null   float64
#  13  PercentSalaryHike        4410 non-null   int64
#  14  StockOptionLevel         4410 non-null   category
#  15  TotalWorkingYears        4401 non-null   float64
#  16  TrainingTimesLastYear    4410 non-null   category
#  17  YearsAtCompany           4410 non-null   int64
#  18  YearsSinceLastPromotion  4410 non-null   int64
#  19  YearsWithCurrManager     4410 non-null   int64
#  20  EnvironmentSatisfaction  4385 non-null   object
#  21  JobSatisfaction          4390 non-null   object
#  22  WorkLifeBalance          4372 non-null   object
#  23  JobInvolvement           4410 non-null   category
#  24  PerformanceRating        4410 non-null   category
# dtypes: category(6), float64(3), int64(7), object(9)
# memory usage: 681.9+ KB

# %%
df_mergeo['EnvironmentSatisfaction'] = df_mergeo['EnvironmentSatisfaction'].fillna('Desconocido')
df_mergeo['JobSatisfaction'] = df_mergeo['JobSatisfaction'].fillna('Desconocido')
df_mergeo['WorkLifeBalance'] = df_mergeo['WorkLifeBalance'].fillna('Desconocido')

# %%
df_mergeo[df_mergeo['EnvironmentSatisfaction'] == 'Desconocido']
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 11     36          0      Travel_Rarely  Research & Development
# 111    31          0      Travel_Rarely  Research & Development
# 195    26          1  Travel_Frequently  Research & Development
# 300    32          0  Travel_Frequently                   Sales
# 405    21          1      Travel_Rarely  Research & Development
# 489    38          0      Travel_Rarely  Research & Development
# 678    45          0  Travel_Frequently  Research & Development
# 846    29          0      Travel_Rarely  Research & Development
# 909    35          1      Travel_Rarely  Research & Development
# 1077   39          0      Travel_Rarely  Research & Development
# 1224   31          0      Travel_Rarely  Research & Development
# 1476   28          1      Travel_Rarely  Research & Development
# 1812   32          0      Travel_Rarely  Research & Development
# 2148   45          0  Travel_Frequently  Research & Development
# 2379   35          1      Travel_Rarely  Research & Development
# 2568   41          0      Travel_Rarely  Research & Development
# 2736   26          0      Travel_Rarely  Research & Development
# 2925   40          0      Travel_Rarely  Research & Development
# 3114   34          0      Travel_Rarely                   Sales
# 3261   34          0      Travel_Rarely                   Sales
# 3387   39          0      Travel_Rarely                   Sales
# 3534   29          0      Travel_Rarely  Research & Development
# 3681   42          0      Travel_Rarely                   Sales
# 3996   45          0         Non-Travel                   Sales
# 4332   31          0      Travel_Rarely                   Sales
#
#       DistanceFromHome Education    EducationField  Gender JobLevel  \
# 11                  28         1     Life Sciences    Male        1
# 111                  1         3     Life Sciences    Male        4
# 195                  2         1     Life Sciences  Female        2
# 300                  4         4     Life Sciences    Male        2
# 405                  1         3           Medical    Male        2
# 489                 24         2             Other  Female        1
# 678                 19         3           Medical    Male        3
# 846                 23         4     Life Sciences  Female        2
# 909                  9         3     Life Sciences    Male        2
# 1077                 2         3  Technical Degree    Male        3
# 1224                 2         2           Medical    Male        2
# 1476                11         2           Medical    Male        2
# 1812                 3         1           Medical    Male        2
# 2148                19         3           Medical    Male        3
# 2379                 9         3     Life Sciences    Male        2
# 2568                 5         3     Life Sciences  Female        1
# 2736                 4         4     Life Sciences  Female        3
# 2925                 2         3     Life Sciences    Male        1
# 3114                 8         2     Life Sciences    Male        1
# 3261                 2         3         Marketing    Male        1
# 3387                 1         1         Marketing    Male        2
# 3534                26         1     Life Sciences    Male        1
# 3681                23         3         Marketing  Female        3
# 3996                 1         4  Technical Degree    Male        1
# 4332                 2         5     Life Sciences    Male        2
#
#                         JobRole MaritalStatus  MonthlyIncome  \
# 11        Laboratory Technician       Married        381.601
# 111             Human Resources        Single        323.971
# 195       Laboratory Technician      Divorced        677.209
# 300             Sales Executive       Married       2129.372
# 405             Sales Executive        Single       1175.200
# 489       Laboratory Technician        Single        262.838
# 678       Laboratory Technician        Single        415.953
# 846   Healthcare Representative       Married        512.681
# 909                     Manager      Divorced       1966.087
# 1077  Healthcare Representative      Divorced       1158.476
# 1224      Laboratory Technician      Divorced        449.175
# 1476            Sales Executive        Single        656.869
# 1812     Manufacturing Director       Married       1941.453
# 2148      Laboratory Technician        Single        415.953
# 2379                    Manager      Divorced       1966.087
# 2568            Sales Executive       Married        748.399
# 2736            Sales Executive       Married        541.157
# 2925     Manufacturing Director      Divorced        307.134
# 3114      Laboratory Technician      Divorced        275.607
# 3261       Sales Representative        Single       1165.256
# 3387         Research Scientist        Single        264.420
# 3534      Laboratory Technician       Married        250.634
# 3681         Research Scientist       Married        298.546
# 3996         Research Scientist       Married       1926.424
# 4332       Sales Representative       Married        308.264
#
#       NumCompaniesWorked  PercentSalaryHike StockOptionLevel  \
# 11                   0.0                 12                2
# 111                  0.0                 24                0
# 195                  0.0                 12                0
# 300                  1.0                 19                0
# 405                  1.0                 13                1
# 489                  8.0                 14                0
# 678                  3.0                 17                1
# 846                  6.0                 18                1
# 909                  6.0                 12                0
# 1077                 8.0                 13                1
# 1224                 1.0                 15                1
# 1476                 2.0                 20                1
# 1812                 1.0                 14                0
# 2148                 3.0                 17                1
# 2379                 6.0                 12                0
# 2568                 5.0                 18                0
# 2736                 7.0                 20                1
# 2925                 1.0                 14                1
# 3114                 3.0                 11                2
# 3261                 1.0                 12                0
# 3387                 0.0                 11                1
# 3534                 1.0                 24                1
# 3681                 0.0                 13                1
# 3996                 4.0                 15                0
# 4332                 8.0                 11                0
#
#       TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 11                 16.0                     2              15
# 111                 3.0                     5               2
# 195                 8.0                     3               7
# 300                10.0                     3              10
# 405                 1.0                     2               1
# 489                19.0                     3               1
# 678                22.0                     2               0
# 846                 5.0                     5               1
# 909                 7.0                     3               2
# 1077                7.0                     3               2
# 1224                5.0                     3               5
# 1476                5.0                     2               0
# 1812               14.0                     2              14
# 2148               22.0                     2               0
# 2379                7.0                     3               2
# 2568               14.0                     3               5
# 2736                5.0                     2               2
# 2925                9.0                     4               9
# 3114               14.0                     2               7
# 3261                6.0                     2               6
# 3387                9.0                     2               8
# 3534               10.0                     1              10
# 3681               21.0                     3              20
# 3996               10.0                     3               8
# 4332                7.0                     3               4
#
#       YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 11                         10                    11             Desconocido
# 111                         2                     2             Desconocido
# 195                         1                     0             Desconocido
# 300                         4                     7             Desconocido
# 405                         0                     0             Desconocido
# 489                         0                     0             Desconocido
# 678                         0                     0             Desconocido
# 846                         0                     0             Desconocido
# 909                         2                     2             Desconocido
# 1077                        2                     2             Desconocido
# 1224                        4                     3             Desconocido
# 1476                        0                     0             Desconocido
# 1812                        6                     8             Desconocido
# 2148                        0                     0             Desconocido
# 2379                        2                     2             Desconocido
# 2568                        1                     4             Desconocido
# 2736                        0                     0             Desconocido
# 2925                        4                     7             Desconocido
# 3114                        5                     7             Desconocido
# 3261                        1                     3             Desconocido
# 3387                        0                     7             Desconocido
# 3534                        0                     8             Desconocido
# 3681                        0                     9             Desconocido
# 3996                        5                     7             Desconocido
# 4332                        0                     2             Desconocido
#
#      JobSatisfaction WorkLifeBalance JobInvolvement PerformanceRating
# 11               4.0             3.0              3                 3
# 111              2.0             3.0              3                 4
# 195              3.0             2.0              3                 3
# 300              4.0             3.0              1                 3
# 405              4.0             2.0              3                 3
# 489              4.0             3.0              4                 3
# 678              2.0             3.0              3                 3
# 846              3.0             2.0              4                 3
# 909              4.0             2.0              1                 3
# 1077             4.0             3.0              3                 3
# 1224             3.0             2.0              3                 3
# 1476             3.0             1.0              3                 4
# 1812             3.0             3.0              2                 3
# 2148             2.0             3.0              3                 3
# 2379             4.0             2.0              1                 3
# 2568             2.0             3.0              3                 3
# 2736             4.0             2.0              3                 4
# 2925             4.0             3.0              2                 3
# 3114             3.0             3.0              4                 3
# 3261             1.0             3.0              3                 3
# 3387             3.0             3.0              2                 3
# 3534             4.0             3.0              3                 4
# 3681             1.0             3.0              3                 3
# 3996             3.0             4.0              2                 3
# 4332             4.0             3.0              4                 3

# %%
df_mergeo
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome Education EducationField  Gender JobLevel  \
# 0                    6         2  Life Sciences  Female        1
# 1                   10         1  Life Sciences  Female        1
# 2                   17         4          Other    Male        4
# 3                    2         5  Life Sciences    Male        3
# 4                   10         1        Medical    Male        1
# ...                ...       ...            ...     ...      ...
# 4405                 5         4        Medical  Female        1
# 4406                 2         4        Medical    Male        1
# 4407                25         2  Life Sciences    Male        2
# 4408                18         2        Medical    Male        1
# 4409                28         3        Medical    Male        2
#
#                         JobRole MaritalStatus  MonthlyIncome  \
# 0     Healthcare Representative       Married       1482.108
# 1            Research Scientist        Single        473.357
# 2               Sales Executive       Married       2184.064
# 3               Human Resources       Married        940.273
# 4               Sales Executive        Single        264.646
# ...                         ...           ...            ...
# 4405         Research Scientist        Single        681.277
# 4406      Laboratory Technician      Divorced        302.727
# 4407            Sales Executive       Married        418.326
# 4408      Laboratory Technician      Divorced        270.974
# 4409      Laboratory Technician      Divorced        617.884
#
#       NumCompaniesWorked  PercentSalaryHike StockOptionLevel  \
# 0                    1.0                 11                0
# 1                    0.0                 23                1
# 2                    1.0                 15                3
# 3                    3.0                 11                3
# 4                    4.0                 12                2
# ...                  ...                ...              ...
# 4405                 3.0                 17                1
# 4406                 2.0                 15                0
# 4407                 0.0                 20                0
# 4408                 0.0                 14                1
# 4409                 0.0                 12                0
#
#       TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 0                   1.0                     6               1
# 1                   6.0                     3               5
# 2                   5.0                     2               5
# 3                  13.0                     5               8
# 4                   9.0                     2               6
# ...                 ...                   ...             ...
# 4405               10.0                     5               3
# 4406               10.0                     2               3
# 4407                5.0                     4               4
# 4408               10.0                     2               9
# 4409                NaN                     6              21
#
#       YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 0                           0                     0                     3.0
# 1                           1                     4                     3.0
# 2                           0                     3                     2.0
# 3                           7                     5                     4.0
# 4                           0                     4                     4.0
# ...                       ...                   ...                     ...
# 4405                        0                     2                     4.0
# 4406                        0                     2                     4.0
# 4407                        1                     2                     1.0
# 4408                        7                     8                     4.0
# 4409                        3                     9                     1.0
#
#      JobSatisfaction WorkLifeBalance JobInvolvement PerformanceRating
# 0                4.0             2.0              3                 3
# 1                2.0             4.0              2                 4
# 2                2.0             1.0              3                 3
# 3                4.0             3.0              2                 3
# 4                1.0             3.0              3                 3
# ...              ...             ...            ...               ...
# 4405             1.0             3.0              3                 3
# 4406             4.0             3.0              2                 3
# 4407             3.0             3.0              3                 4
# 4408             1.0             3.0              2                 3
# 4409             3.0     Desconocido              4                 3
#
# [4410 rows x 25 columns]

# %%
df_mergeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   int64
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   category
#  6   EducationField           4410 non-null   object
#  7   Gender                   4410 non-null   object
#  8   JobLevel                 4410 non-null   category
#  9   JobRole                  4410 non-null   object
#  10  MaritalStatus            4410 non-null   object
#  11  MonthlyIncome            4410 non-null   float64
#  12  NumCompaniesWorked       4391 non-null   float64
#  13  PercentSalaryHike        4410 non-null   int64
#  14  StockOptionLevel         4410 non-null   category
#  15  TotalWorkingYears        4401 non-null   float64
#  16  TrainingTimesLastYear    4410 non-null   category
#  17  YearsAtCompany           4410 non-null   int64
#  18  YearsSinceLastPromotion  4410 non-null   int64
#  19  YearsWithCurrManager     4410 non-null   int64
#  20  EnvironmentSatisfaction  4410 non-null   object
#  21  JobSatisfaction          4410 non-null   object
#  22  WorkLifeBalance          4410 non-null   object
#  23  JobInvolvement           4410 non-null   category
#  24  PerformanceRating        4410 non-null   category
# dtypes: category(6), float64(3), int64(7), object(9)
# memory usage: 681.9+ KB

# %%
df_mergeo.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction     0
# JobSatisfaction             0
# WorkLifeBalance             0
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %% [markdown]
# ### Columnas que tengo que imputar

# %%
df_imputar = df_mergeo[['NumCompaniesWorked', 'TotalWorkingYears']]

# %%
imputer = IterativeImputer(estimator=DecisionTreeClassifier(), max_iter=10, random_state=42) #hace 10 iteraciones para completarse
it_imputados = imputer.fit_transform(X=df_imputar) #relleno mis nulos
df_num_sin_nulos = pd.DataFrame(it_imputados, columns= df_imputar.columns) #convierte lo anterior a df, usando las columnas que coincidan
df_full = df_mergeo.copy() 
df_full[df_imputar.columns] = df_num_sin_nulos # mi df sin nulos, le pongo esos datos sin nulos
df_full.isna().sum() #verifico que no tengo nulos en las numéricas
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64

# %%
df_full['NumCompaniesWorked'].value_counts()
# Out:
# NumCompaniesWorked
# 1.0    1574
# 0.0     587
# 3.0     475
# 2.0     439
# 4.0     415
# 7.0     222
# 6.0     208
# 5.0     187
# 9.0     156
# 8.0     147
# Name: count, dtype: int64

# %%
df_mergeo['NumCompaniesWorked'].value_counts()
# Out:
# NumCompaniesWorked
# 1.0    1558
# 0.0     586
# 3.0     474
# 2.0     438
# 4.0     415
# 7.0     222
# 6.0     208
# 5.0     187
# 9.0     156
# 8.0     147
# Name: count, dtype: int64

# %%
df_mergeo.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction     0
# JobSatisfaction             0
# WorkLifeBalance             0
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
df_full.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome Education EducationField  Gender JobLevel  \
# 0                 6         2  Life Sciences  Female        1
# 1                10         1  Life Sciences  Female        1
# 2                17         4          Other    Male        4
# 3                 2         5  Life Sciences    Male        3
# 4                10         1        Medical    Male        1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married       1482.108                 1.0
# 1         Research Scientist        Single        473.357                 0.0
# 2            Sales Executive       Married       2184.064                 1.0
# 3            Human Resources       Married        940.273                 3.0
# 4            Sales Executive        Single        264.646                 4.0
#
#    PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 0                 11                0                1.0
# 1                 23                1                6.0
# 2                 15                3                5.0
# 3                 11                3               13.0
# 4                 12                2                9.0
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                     6               1                        0
# 1                     3               5                        1
# 2                     2               5                        0
# 3                     5               8                        7
# 4                     2               6                        0
#
#    YearsWithCurrManager EnvironmentSatisfaction JobSatisfaction  \
# 0                     0                     3.0             4.0
# 1                     4                     3.0             2.0
# 2                     3                     2.0             2.0
# 3                     5                     4.0             4.0
# 4                     4                     4.0             1.0
#
#   WorkLifeBalance JobInvolvement PerformanceRating
# 0             2.0              3                 3
# 1             4.0              2                 4
# 2             1.0              3                 3
# 3             3.0              2                 3
# 4             3.0              3                 3

# %%
df_full.describe()
# Out:
#                Age    Attrition  DistanceFromHome  MonthlyIncome  \
# count  4410.000000  4410.000000       4410.000000    4410.000000
# mean     36.923810     0.161224          9.192517     734.831236
# std       9.133301     0.367780          8.105026     531.878441
# min      18.000000     0.000000          1.000000     114.017000
# 25%      30.000000     0.000000          2.000000     328.943000
# 50%      36.000000     0.000000          7.000000     555.847000
# 75%      43.000000     0.000000         14.000000     946.940000
# max      60.000000     1.000000         29.000000    2259.887000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4410.000000        4410.000000         4410.00000
# mean             2.687982          15.209524           11.27415
# std              2.495933           3.659108            7.77574
# min              0.000000          11.000000            0.00000
# 25%              1.000000          12.000000            6.00000
# 50%              2.000000          14.000000           10.00000
# 75%              4.000000          18.000000           15.00000
# max              9.000000          25.000000           40.00000
#
#        YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# count     4410.000000              4410.000000           4410.000000
# mean         7.008163                 2.187755              4.123129
# std          6.125135                 3.221699              3.567327
# min          0.000000                 0.000000              0.000000
# 25%          3.000000                 0.000000              2.000000
# 50%          5.000000                 1.000000              3.000000
# 75%          9.000000                 3.000000              7.000000
# max         40.000000                15.000000             17.000000

# %%
# #simple imputer
# df_num = df_mergeo.select_dtypes(include=np.number)
# df_num.drop(columns='price', inplace=True)
# imputer_knn = KNNImputer(n_neighbors=5) #busca 5 vecinos para completarse, por defecto 5
# knn_imputados = imputer_knn.fit_transform(df_num) #relleno mis nulos
# df_num_sin_nulos = pd.DataFrame(knn_imputados, columns= df_num.columns)
# df_knn = df_mergeo.copy()
# df_knn[df_num.columns] = df_num_sin_nulos # mi df sin nulos, le pongo los datos en df_knn, en las columnas numericas (esta en corchetes)
# df_knn.isna().sum() #verifico que no tengo nulos en las numéricas

# %%
df_full.to_pickle('../datos/datos_sin_nulos.pkl')

# %% [markdown]
# ## Desbalanceo

# %%
df_full ['Attrition'].value_counts(normalize=True) * 100
# Out:
# Attrition
# 0    83.877551
# 1    16.122449
# Name: proportion, dtype: float64

# %% [markdown]
# Tengo un desbalanceo bastante notorio pero, de momento, para este modelo no voy a balancear.

# %% [markdown]
# # Outliers

# %%
contaminacion = [0.01, 0.05, 0.1]
vecinos = [25,35,50]

# %%
combinaciones_lof = list(product(contaminacion, vecinos))
combinaciones_lof
# Out:
# [(0.01, 25),
#  (0.01, 35),
#  (0.01, 50),
#  (0.05, 25),
#  (0.05, 35),
#  (0.05, 50),
#  (0.1, 25),
#  (0.1, 35),
#  (0.1, 50)]

# %%
cols_num = df_full.select_dtypes([int, float]).columns

# %%
cols_num
# Out:
# Index(['Age', 'Attrition', 'DistanceFromHome', 'MonthlyIncome',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
for cont, vec in tqdm(combinaciones_lof):
    lof = LocalOutlierFactor(n_neighbors=vec, #semilla de datos aleatorios
                        algorithm='auto',
                        contamination=cont,
                        n_jobs=-1) #nucleos del ordenador

    df_full[f'outliers_lof_{cont}_{vec}'] = lof.fit_predict(df_full[['Age', 'DistanceFromHome', 'MonthlyIncome','NumCompaniesWorked',
                                                                     'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany','YearsSinceLastPromotion',
                                                                       'YearsWithCurrManager']])
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 11.01it/s]

# %%
columnas_lof = df_full.filter(like='outlier').columns 
columnas_lof
# Out:
# Index(['outliers_lof_0.01_25', 'outliers_lof_0.01_35', 'outliers_lof_0.01_50',
#        'outliers_lof_0.05_25', 'outliers_lof_0.05_35', 'outliers_lof_0.05_50',
#        'outliers_lof_0.1_25', 'outliers_lof_0.1_35', 'outliers_lof_0.1_50'],
#       dtype='object')

# %%
combinaciones_lof
# Out:
# [(0.01, 25),
#  (0.01, 35),
#  (0.01, 50),
#  (0.05, 25),
#  (0.05, 35),
#  (0.05, 50),
#  (0.1, 25),
#  (0.1, 35),
#  (0.1, 50)]

# %%
filtered_df = df_full[(df_full[columnas_lof] == -1).all(axis=1)]

# %%
df_full.describe()
# Out:
#                Age    Attrition  DistanceFromHome  MonthlyIncome  \
# count  4410.000000  4410.000000       4410.000000    4410.000000
# mean     36.923810     0.161224          9.192517     734.831236
# std       9.133301     0.367780          8.105026     531.878441
# min      18.000000     0.000000          1.000000     114.017000
# 25%      30.000000     0.000000          2.000000     328.943000
# 50%      36.000000     0.000000          7.000000     555.847000
# 75%      43.000000     0.000000         14.000000     946.940000
# max      60.000000     1.000000         29.000000    2259.887000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4410.000000        4410.000000         4410.00000
# mean             2.687982          15.209524           11.27415
# std              2.495933           3.659108            7.77574
# min              0.000000          11.000000            0.00000
# 25%              1.000000          12.000000            6.00000
# 50%              2.000000          14.000000           10.00000
# 75%              4.000000          18.000000           15.00000
# max              9.000000          25.000000           40.00000
#
#        YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# count     4410.000000              4410.000000           4410.000000
# mean         7.008163                 2.187755              4.123129
# std          6.125135                 3.221699              3.567327
# min          0.000000                 0.000000              0.000000
# 25%          3.000000                 0.000000              2.000000
# 50%          5.000000                 1.000000              3.000000
# 75%          9.000000                 3.000000              7.000000
# max         40.000000                15.000000             17.000000
#
#        outliers_lof_0.01_25  outliers_lof_0.01_35  outliers_lof_0.01_50  \
# count           4410.000000           4410.000000           4410.000000
# mean               0.979592              0.979592              0.979592
# std                0.201020              0.201020              0.201020
# min               -1.000000             -1.000000             -1.000000
# 25%                1.000000              1.000000              1.000000
# 50%                1.000000              1.000000              1.000000
# 75%                1.000000              1.000000              1.000000
# max                1.000000              1.000000              1.000000
#
#        outliers_lof_0.05_25  outliers_lof_0.05_35  outliers_lof_0.05_50  \
# count           4410.000000           4410.000000           4410.000000
# mean               0.900680              0.900680              0.900227
# std                0.434532              0.434532              0.435471
# min               -1.000000             -1.000000             -1.000000
# 25%                1.000000              1.000000              1.000000
# 50%                1.000000              1.000000              1.000000
# 75%                1.000000              1.000000              1.000000
# max                1.000000              1.000000              1.000000
#
#        outliers_lof_0.1_25  outliers_lof_0.1_35  outliers_lof_0.1_50
# count          4410.000000          4410.000000          4410.000000
# mean              0.800454             0.800000             0.800000
# std               0.599463             0.600068             0.600068
# min              -1.000000            -1.000000            -1.000000
# 25%               1.000000             1.000000             1.000000
# 50%               1.000000             1.000000             1.000000
# 75%               1.000000             1.000000             1.000000
# max               1.000000             1.000000             1.000000

# %%
filtered_df
# Out:
#       Age  Attrition BusinessTravel              Department  DistanceFromHome  \
# 12     55          0  Travel_Rarely  Research & Development                14
# 215    49          0  Travel_Rarely                   Sales                21
# 431    20          1  Travel_Rarely  Research & Development                29
# 652    23          0  Travel_Rarely                   Sales                 2
# 656    55          0     Non-Travel  Research & Development                27
# 933    31          0  Travel_Rarely  Research & Development                28
# 1402   52          0  Travel_Rarely  Research & Development                 2
# 1482   55          0  Travel_Rarely  Research & Development                14
# 1685   49          0  Travel_Rarely                   Sales                21
# 1901   20          1  Travel_Rarely  Research & Development                29
# 2122   23          0  Travel_Rarely                   Sales                 2
# 2126   55          0     Non-Travel  Research & Development                27
# 2403   31          0  Travel_Rarely  Research & Development                28
# 2872   52          0  Travel_Rarely  Research & Development                 2
# 2952   55          0  Travel_Rarely  Research & Development                14
# 3155   49          0  Travel_Rarely                   Sales                21
# 3371   20          1  Travel_Rarely  Research & Development                29
# 3592   23          0  Travel_Rarely                   Sales                 2
# 3596   55          0     Non-Travel  Research & Development                27
# 3873   31          0  Travel_Rarely  Research & Development                28
# 4342   52          0  Travel_Rarely  Research & Development                 2
#
#      Education    EducationField  Gender JobLevel                JobRole  \
# 12           4     Life Sciences  Female        1        Sales Executive
# 215          1     Life Sciences    Male        1        Sales Executive
# 431          3     Life Sciences  Female        3  Laboratory Technician
# 652          3           Medical    Male        3  Laboratory Technician
# 656          3     Life Sciences  Female        2                Manager
# 933          4  Technical Degree  Female        2        Sales Executive
# 1402         4           Medical  Female        2   Sales Representative
# 1482         4     Life Sciences  Female        1        Sales Executive
# 1685         1     Life Sciences    Male        1        Sales Executive
# 1901         3     Life Sciences  Female        3  Laboratory Technician
# 2122         3           Medical    Male        3  Laboratory Technician
# 2126         3     Life Sciences  Female        2                Manager
# 2403         4  Technical Degree  Female        2        Sales Executive
# 2872         4           Medical  Female        2   Sales Representative
# 2952         4     Life Sciences  Female        1        Sales Executive
# 3155         1     Life Sciences    Male        1        Sales Executive
# 3371         3     Life Sciences  Female        3  Laboratory Technician
# 3592         3           Medical    Male        3  Laboratory Technician
# 3596         3     Life Sciences  Female        2                Manager
# 3873         4  Technical Degree  Female        2        Sales Executive
# 4342         4           Medical  Female        2   Sales Representative
#
#      MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 12          Single        625.794                 0.0                 17
# 215       Divorced        453.243                 1.0                 18
# 431         Single        305.891                 1.0                 11
# 652        Married        212.214                 1.0                 13
# 656       Divorced        549.067                 1.0                 24
# 933        Married       1439.846                 1.0                 11
# 1402       Married        399.681                 0.0                 11
# 1482        Single        625.794                 0.0                 17
# 1685      Divorced        453.243                 1.0                 18
# 1901        Single        305.891                 1.0                 11
# 2122       Married        212.214                 1.0                 13
# 2126      Divorced        549.067                 1.0                 24
# 2403       Married       1439.846                 1.0                 11
# 2872       Married        399.681                 0.0                 11
# 2952        Single        625.794                 0.0                 17
# 3155      Divorced        453.243                 1.0                 18
# 3371        Single        305.891                 1.0                 11
# 3592       Married        212.214                 1.0                 13
# 3596      Divorced        549.067                 1.0                 24
# 3873       Married       1439.846                 1.0                 11
# 4342       Married        399.681                 0.0                 11
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 12                  0               37.0                     2
# 215                 2               31.0                     2
# 431                 0                1.0                     2
# 652                 1                1.0                     2
# 656                 1               34.0                     3
# 933                 0               10.0                     4
# 1402                1               34.0                     3
# 1482                0               37.0                     2
# 1685                2               31.0                     2
# 1901                0                1.0                     2
# 2122                1                1.0                     2
# 2126                1               34.0                     3
# 2403                0               10.0                     4
# 2872                1               34.0                     3
# 2952                0               37.0                     2
# 3155                2               31.0                     2
# 3371                0                1.0                     2
# 3592                1                1.0                     2
# 3596                1               34.0                     3
# 3873                0               10.0                     4
# 4342                1               34.0                     3
#
#       YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# 12                36                        4                    13
# 215               31                        0                     9
# 431                1                        0                     0
# 652                1                        0                     1
# 656               33                       15                     0
# 933               10                        0                     2
# 1402              33                       11                     9
# 1482              36                        4                    13
# 1685              31                        0                     9
# 1901               1                        0                     0
# 2122               1                        0                     1
# 2126              33                       15                     0
# 2403              10                        0                     2
# 2872              33                       11                     9
# 2952              36                        4                    13
# 3155              31                        0                     9
# 3371               1                        0                     0
# 3592               1                        0                     1
# 3596              33                       15                     0
# 3873              10                        0                     2
# 4342              33                       11                     9
#
#      EnvironmentSatisfaction JobSatisfaction WorkLifeBalance JobInvolvement  \
# 12                       4.0             1.0             3.0              3
# 215                      4.0             3.0             3.0              1
# 431                      1.0             1.0             3.0              3
# 652                      4.0             3.0             3.0              3
# 656                      4.0             2.0             3.0              4
# 933                      1.0             4.0             3.0              2
# 1402                     3.0             3.0             3.0              3
# 1482                     4.0             1.0             3.0              3
# 1685                     4.0             3.0             3.0              1
# 1901                     1.0             1.0             3.0              3
# 2122                     4.0             3.0             3.0              3
# 2126                     4.0             2.0             3.0              4
# 2403                     1.0             4.0             3.0              2
# 2872                     3.0             3.0             3.0              3
# 2952                     4.0             1.0             3.0              3
# 3155                     4.0             3.0             3.0              1
# 3371                     1.0             1.0             3.0              3
# 3592                     4.0             3.0             3.0              3
# 3596                     4.0             2.0             3.0              4
# 3873                     1.0             4.0             3.0              2
# 4342                     3.0             3.0             3.0              3
#
#      PerformanceRating  outliers_lof_0.01_25  outliers_lof_0.01_35  \
# 12                   3                    -1                    -1
# 215                  3                    -1                    -1
# 431                  3                    -1                    -1
# 652                  3                    -1                    -1
# 656                  4                    -1                    -1
# 933                  3                    -1                    -1
# 1402                 3                    -1                    -1
# 1482                 3                    -1                    -1
# 1685                 3                    -1                    -1
# 1901                 3                    -1                    -1
# 2122                 3                    -1                    -1
# 2126                 4                    -1                    -1
# 2403                 3                    -1                    -1
# 2872                 3                    -1                    -1
# 2952                 3                    -1                    -1
# 3155                 3                    -1                    -1
# 3371                 3                    -1                    -1
# 3592                 3                    -1                    -1
# 3596                 4                    -1                    -1
# 3873                 3                    -1                    -1
# 4342                 3                    -1                    -1
#
#       outliers_lof_0.01_50  outliers_lof_0.05_25  outliers_lof_0.05_35  \
# 12                      -1                    -1                    -1
# 215                     -1                    -1                    -1
# 431                     -1                    -1                    -1
# 652                     -1                    -1                    -1
# 656                     -1                    -1                    -1
# 933                     -1                    -1                    -1
# 1402                    -1                    -1                    -1
# 1482                    -1                    -1                    -1
# 1685                    -1                    -1                    -1
# 1901                    -1                    -1                    -1
# 2122                    -1                    -1                    -1
# 2126                    -1                    -1                    -1
# 2403                    -1                    -1                    -1
# 2872                    -1                    -1                    -1
# 2952                    -1                    -1                    -1
# 3155                    -1                    -1                    -1
# 3371                    -1                    -1                    -1
# 3592                    -1                    -1                    -1
# 3596                    -1                    -1                    -1
# 3873                    -1                    -1                    -1
# 4342                    -1                    -1                    -1
#
#       outliers_lof_0.05_50  outliers_lof_0.1_25  outliers_lof_0.1_35  \
# 12                      -1                   -1                   -1
# 215                     -1                   -1                   -1
# 431                     -1                   -1                   -1
# 652                     -1                   -1                   -1
# 656                     -1                   -1                   -1
# 933                     -1                   -1                   -1
# 1402                    -1                   -1                   -1
# 1482                    -1                   -1                   -1
# 1685                    -1                   -1                   -1
# 1901                    -1                   -1                   -1
# 2122                    -1                   -1                   -1
# 2126                    -1                   -1                   -1
# 2403                    -1                   -1                   -1
# 2872                    -1                   -1                   -1
# 2952                    -1                   -1                   -1
# 3155                    -1                   -1                   -1
# 3371                    -1                   -1                   -1
# 3592                    -1                   -1                   -1
# 3596                    -1                   -1                   -1
# 3873                    -1                   -1                   -1
# 4342                    -1                   -1                   -1
#
#       outliers_lof_0.1_50
# 12                     -1
# 215                    -1
# 431                    -1
# 652                    -1
# 656                    -1
# 933                    -1
# 1402                   -1
# 1482                   -1
# 1685                   -1
# 1901                   -1
# 2122                   -1
# 2126                   -1
# 2403                   -1
# 2872                   -1
# 2952                   -1
# 3155                   -1
# 3371                   -1
# 3592                   -1
# 3596                   -1
# 3873                   -1
# 4342                   -1

# %%
df_sin_out = df_full[~df_full.index.isin(filtered_df.index)] # aqui me quito los outliers al 100% multivariados

# %%
df_sin_out.shape
# Out:
# (4389, 34)

# %% [markdown]
# ### Señalo los datos que presentan 60% de outliers

# %%
fragmento = 0.6 * len(columnas_lof)
df_fragmento_60 = df_sin_out[df_sin_out[columnas_lof].eq(-1).sum(axis=1) >= fragmento]

# %%
df_fragmento_60
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 42     41          0      Travel_Rarely  Research & Development
# 121    55          0      Travel_Rarely                   Sales
# 167    50          0      Travel_Rarely                   Sales
# 235    44          0      Travel_Rarely                   Sales
# 286    47          0  Travel_Frequently  Research & Development
# ...   ...        ...                ...                     ...
# 4257   59          0         Non-Travel  Research & Development
# 4273   33          0         Non-Travel                   Sales
# 4309   58          0      Travel_Rarely                   Sales
# 4384   59          0      Travel_Rarely  Research & Development
# 4396   45          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome Education    EducationField  Gender JobLevel  \
# 42                  29         1     Life Sciences    Male        1
# 121                 26         3         Marketing    Male        1
# 167                 10         4     Life Sciences  Female        3
# 235                 29         4         Marketing    Male        2
# 286                 27         3     Life Sciences    Male        1
# ...                ...       ...               ...     ...      ...
# 4257                12         2     Life Sciences    Male        2
# 4273                 7         3     Life Sciences    Male        2
# 4309                 3         3         Marketing  Female        1
# 4384                 4         4  Technical Degree    Male        1
# 4396                18         1     Life Sciences  Female        2
#
#                         JobRole MaritalStatus  MonthlyIncome  \
# 42        Laboratory Technician        Single        268.827
# 121       Laboratory Technician        Single       1180.624
# 167                     Manager       Married        540.931
# 235             Sales Executive        Single        220.463
# 286          Research Scientist      Divorced        614.833
# ...                         ...           ...            ...
# 4257            Sales Executive       Married        533.699
# 4273            Sales Executive       Married       1270.685
# 4309         Research Scientist       Married        588.278
# 4384  Healthcare Representative       Married        311.880
# 4396       Sales Representative       Married        656.643
#
#       NumCompaniesWorked  PercentSalaryHike StockOptionLevel  \
# 42                   1.0                 12                0
# 121                  2.0                 13                0
# 167                  0.0                 12                0
# 235                  4.0                 22                3
# 286                  9.0                 22                1
# ...                  ...                ...              ...
# 4257                 9.0                 14                0
# 4273                 0.0                 21                0
# 4309                 4.0                 11                3
# 4384                 8.0                 11                0
# 4396                 0.0                 14                0
#
#       TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 42                 22.0                     6              22
# 121                30.0                     3               5
# 167                28.0                     3              27
# 235                10.0                     4               2
# 286                28.0                     6              22
# ...                 ...                   ...             ...
# 4257               30.0                     0               3
# 4273                8.0                     3               7
# 4309                9.0                     4               1
# 4384                7.0                     3               2
# 4396               25.0                     4              24
#
#       YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 42                          0                     4                     4.0
# 121                         1                     2                     3.0
# 167                        15                     7                     2.0
# 235                         0                     2                     1.0
# 286                        11                    13                     4.0
# ...                       ...                   ...                     ...
# 4257                        2                     2                     3.0
# 4273                        0                     7                     3.0
# 4309                        0                     0                     2.0
# 4384                        2                     2                     2.0
# 4396                        1                     7                     3.0
#
#      JobSatisfaction WorkLifeBalance JobInvolvement PerformanceRating  \
# 42               2.0             3.0              3                 3
# 121              4.0             3.0              3                 3
# 167              3.0             3.0              3                 3
# 235              3.0             4.0              4                 4
# 286              3.0             2.0              2                 4
# ...              ...             ...            ...               ...
# 4257             4.0             3.0              3                 3
# 4273             2.0             4.0              3                 4
# 4309             2.0             2.0              1                 3
# 4384             3.0             2.0              4                 3
# 4396             4.0             3.0              2                 3
#
#       outliers_lof_0.01_25  outliers_lof_0.01_35  outliers_lof_0.01_50  \
# 42                       1                     1                     1
# 121                      1                     1                     1
# 167                      1                    -1                     1
# 235                     -1                    -1                     1
# 286                      1                     1                     1
# ...                    ...                   ...                   ...
# 4257                     1                     1                     1
# 4273                     1                     1                     1
# 4309                     1                     1                     1
# 4384                     1                     1                     1
# 4396                     1                     1                     1
#
#       outliers_lof_0.05_25  outliers_lof_0.05_35  outliers_lof_0.05_50  \
# 42                      -1                    -1                    -1
# 121                     -1                    -1                    -1
# 167                     -1                    -1                    -1
# 235                     -1                    -1                    -1
# 286                     -1                    -1                    -1
# ...                    ...                   ...                   ...
# 4257                    -1                    -1                    -1
# 4273                    -1                    -1                    -1
# 4309                    -1                    -1                    -1
# 4384                    -1                    -1                    -1
# 4396                    -1                    -1                    -1
#
#       outliers_lof_0.1_25  outliers_lof_0.1_35  outliers_lof_0.1_50
# 42                     -1                   -1                   -1
# 121                    -1                   -1                   -1
# 167                    -1                   -1                   -1
# 235                    -1                   -1                   -1
# 286                    -1                   -1                   -1
# ...                   ...                  ...                  ...
# 4257                   -1                   -1                   -1
# 4273                   -1                   -1                   -1
# 4309                   -1                   -1                   -1
# 4384                   -1                   -1                   -1
# 4396                   -1                   -1                   -1
#
# [114 rows x 34 columns]

# %%
df_sin_out.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome Education EducationField  Gender JobLevel  \
# 0                 6         2  Life Sciences  Female        1
# 1                10         1  Life Sciences  Female        1
# 2                17         4          Other    Male        4
# 3                 2         5  Life Sciences    Male        3
# 4                10         1        Medical    Male        1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married       1482.108                 1.0
# 1         Research Scientist        Single        473.357                 0.0
# 2            Sales Executive       Married       2184.064                 1.0
# 3            Human Resources       Married        940.273                 3.0
# 4            Sales Executive        Single        264.646                 4.0
#
#    PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 0                 11                0                1.0
# 1                 23                1                6.0
# 2                 15                3                5.0
# 3                 11                3               13.0
# 4                 12                2                9.0
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                     6               1                        0
# 1                     3               5                        1
# 2                     2               5                        0
# 3                     5               8                        7
# 4                     2               6                        0
#
#    YearsWithCurrManager EnvironmentSatisfaction JobSatisfaction  \
# 0                     0                     3.0             4.0
# 1                     4                     3.0             2.0
# 2                     3                     2.0             2.0
# 3                     5                     4.0             4.0
# 4                     4                     4.0             1.0
#
#   WorkLifeBalance JobInvolvement PerformanceRating  outliers_lof_0.01_25  \
# 0             2.0              3                 3                     1
# 1             4.0              2                 4                     1
# 2             1.0              3                 3                     1
# 3             3.0              2                 3                     1
# 4             3.0              3                 3                     1
#
#    outliers_lof_0.01_35  outliers_lof_0.01_50  outliers_lof_0.05_25  \
# 0                     1                     1                     1
# 1                     1                     1                     1
# 2                     1                     1                     1
# 3                     1                     1                     1
# 4                     1                     1                     1
#
#    outliers_lof_0.05_35  outliers_lof_0.05_50  outliers_lof_0.1_25  \
# 0                     1                     1                    1
# 1                     1                     1                    1
# 2                     1                     1                    1
# 3                     1                     1                    1
# 4                     1                     1                    1
#
#    outliers_lof_0.1_35  outliers_lof_0.1_50
# 0                    1                    1
# 1                    1                    1
# 2                    1                    1
# 3                    1                    1
# 4                    1                    1

# %%
df_sin_out.drop(columns=columnas_lof, inplace=True)

# %%
df_sin_out.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome Education EducationField  Gender JobLevel  \
# 0                 6         2  Life Sciences  Female        1
# 1                10         1  Life Sciences  Female        1
# 2                17         4          Other    Male        4
# 3                 2         5  Life Sciences    Male        3
# 4                10         1        Medical    Male        1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married       1482.108                 1.0
# 1         Research Scientist        Single        473.357                 0.0
# 2            Sales Executive       Married       2184.064                 1.0
# 3            Human Resources       Married        940.273                 3.0
# 4            Sales Executive        Single        264.646                 4.0
#
#    PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 0                 11                0                1.0
# 1                 23                1                6.0
# 2                 15                3                5.0
# 3                 11                3               13.0
# 4                 12                2                9.0
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                     6               1                        0
# 1                     3               5                        1
# 2                     2               5                        0
# 3                     5               8                        7
# 4                     2               6                        0
#
#    YearsWithCurrManager EnvironmentSatisfaction JobSatisfaction  \
# 0                     0                     3.0             4.0
# 1                     4                     3.0             2.0
# 2                     3                     2.0             2.0
# 3                     5                     4.0             4.0
# 4                     4                     4.0             1.0
#
#   WorkLifeBalance JobInvolvement PerformanceRating
# 0             2.0              3                 3
# 1             4.0              2                 4
# 2             1.0              3                 3
# 3             3.0              2                 3
# 4             3.0              3                 3

# %%
df_sin_out.to_pickle('../datos/df_sin_out.pkl')

# %%
df_sin_out.describe()
# Out:
#                Age    Attrition  DistanceFromHome  MonthlyIncome  \
# count  4389.000000  4389.000000       4389.000000    4389.000000
# mean     36.905673     0.161312          9.152427     735.622817
# std       9.097353     0.367861          8.068178     532.384117
# min      18.000000     0.000000          1.000000     114.017000
# 25%      30.000000     0.000000          2.000000     328.943000
# 50%      36.000000     0.000000          7.000000     557.768000
# 75%      43.000000     0.000000         14.000000     947.053000
# max      60.000000     1.000000         29.000000    2259.887000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4389.000000        4389.000000        4389.000000
# mean             2.697425          15.210526          11.226931
# std              2.497956           3.654192           7.692797
# min              0.000000          11.000000           0.000000
# 25%              1.000000          12.000000           6.000000
# 50%              2.000000          14.000000          10.000000
# 75%              4.000000          18.000000          15.000000
# max              9.000000          25.000000          40.000000
#
#        YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# count     4389.000000              4389.000000           4389.000000
# mean         6.942584                 2.177717              4.119617
# std          5.978721                 3.201291              3.559118
# min          0.000000                 0.000000              0.000000
# 25%          3.000000                 0.000000              2.000000
# 50%          5.000000                 1.000000              3.000000
# 75%          9.000000                 3.000000              7.000000
# max         40.000000                15.000000             17.000000

# %%
df_sin_out['JobLevel'].value_counts(normalize=True)*100
# Out:
# JobLevel
# 1    36.978811
# 2    36.295284
# 3    14.764183
# 4     7.245386
# 5     4.716336
# Name: proportion, dtype: float64

# %%
df_duplicados = df_mergeo[df_mergeo.duplicated()]

# %%
df_duplicados['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# 0    0.838209
# 1    0.161791
# Name: proportion, dtype: float64

# %%
df_sin_out.shape
# Out:
# (4389, 25)

# %%
df_duplicados.shape
# Out:
# (2837, 25)

# %%
df_duplicados[df_duplicados.duplicated]
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 2941   31          1  Travel_Frequently  Research & Development
# 2942   32          0  Travel_Frequently  Research & Development
# 2943   38          0         Non-Travel  Research & Development
# 2944   32          0      Travel_Rarely  Research & Development
# 2945   46          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4403   39          0  Travel_Frequently  Research & Development
# 4404   29          0      Travel_Rarely                   Sales
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome Education EducationField  Gender JobLevel  \
# 2941                10         1  Life Sciences  Female        1
# 2942                17         4          Other    Male        4
# 2943                 2         5  Life Sciences    Male        3
# 2944                10         1        Medical    Male        1
# 2945                 8         3  Life Sciences  Female        4
# ...                ...       ...            ...     ...      ...
# 4403                22         3        Medical  Female        1
# 4404                 4         3          Other  Female        2
# 4405                 5         4        Medical  Female        1
# 4406                 2         4        Medical    Male        1
# 4407                25         2  Life Sciences    Male        2
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 2941      Research Scientist        Single        473.357                 0.0
# 2942         Sales Executive       Married       2184.064                 1.0
# 2943         Human Resources       Married        940.273                 3.0
# 2944         Sales Executive        Single        264.646                 4.0
# 2945       Research Director       Married        460.023                 3.0
# ...                      ...           ...            ...                 ...
# 4403  Manufacturing Director        Single       1465.045                 0.0
# 4404         Human Resources        Single        399.907                 1.0
# 4405      Research Scientist        Single        681.277                 3.0
# 4406   Laboratory Technician      Divorced        302.727                 2.0
# 4407         Sales Executive       Married        418.326                 0.0
#
#       PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 2941                 23                1                6.0
# 2942                 15                3                5.0
# 2943                 11                3               13.0
# 2944                 12                2                9.0
# 2945                 13                0               28.0
# ...                 ...              ...                ...
# 4403                 19                1               20.0
# 4404                 18                0                6.0
# 4405                 17                1               10.0
# 4406                 15                0               10.0
# 4407                 20                0                5.0
#
#      TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 2941                     3               5                        1
# 2942                     2               5                        0
# 2943                     5               8                        7
# 2944                     2               6                        0
# 2945                     5               7                        7
# ...                    ...             ...                      ...
# 4403                     2              19                       11
# 4404                     2               6                        1
# 4405                     5               3                        0
# 4406                     2               3                        0
# 4407                     4               4                        1
#
#       YearsWithCurrManager EnvironmentSatisfaction JobSatisfaction  \
# 2941                     4                     3.0             2.0
# 2942                     3                     2.0             2.0
# 2943                     5                     4.0             4.0
# 2944                     4                     4.0             1.0
# 2945                     7                     3.0             2.0
# ...                    ...                     ...             ...
# 4403                     8                     3.0             3.0
# 4404                     5                     3.0             4.0
# 4405                     2                     4.0             1.0
# 4406                     2                     4.0             4.0
# 4407                     2                     1.0             3.0
#
#      WorkLifeBalance JobInvolvement PerformanceRating
# 2941             4.0              2                 4
# 2942             1.0              3                 3
# 2943             3.0              2                 3
# 2944             3.0              3                 3
# 2945             2.0              3                 3
# ...              ...            ...               ...
# 4403             3.0              3                 3
# 4404             3.0              2                 3
# 4405             3.0              3                 3
# 4406             3.0              2                 3
# 4407             3.0              3                 4
#
# [1368 rows x 25 columns]
